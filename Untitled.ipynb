# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.2.1'

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello ",end='')
print("world")
# Out:
# hello world

# %%
print("hello","world")
# Out:
# hello world

# %%
a = 7
b =7.7
c = "hello"
print(a,b,c)
# Out:
# 7 7.7 hello

# %%
print(a,type(a))
print(b,type(b))
print(c,type(c))
# Out:
# 7 <class 'int'>
# 7.7 <class 'float'>
# hello <class 'str'>

# %%
var1 =3+5.3j; var2=complex(3,5.3); var3=8.3e16
print(var1,var2,var3)
# Out:
# (3+5.3j) (3+5.3j) 8.3e+16

# %%
i_love_you=True
you_love_me=False
print(i_love_you,type(i_love_you))
print(you_love_me,type(you_love_me))
# Out:
# True <class 'bool'>
# False <class 'bool'>

# %% [markdown]
# 结果符号与除数相同

# %%
-10 % 3

# %%
10 % -3
# Out:
# -2

# %% [markdown]
# 幂运算 **

# %%
10 ** 3
# Out:
# 1000

# %% [markdown]
# 比较运算

# %%
10 == 3
# Out:
# False

# %%
3 == 3.0
# Out:
# True

# %%
10 + 3 == 13 #先做算数运算，再比较
# Out:
# True

# %% [markdown]
# 逻辑运算

# %%
0 == False   #逻辑运算中False的值就是0
# Out:
# True

# %%
True == 1  #逻辑运算中True的值就是1
# Out:
# True

# %%
5 == True  #非0的值被视作True，但不等于True，只有1等于True
# Out:
# False

# %% [markdown]
# 如何输出he said  "hello" _____字符串可以用单引号也可以用双引号

# %%
print("he said 'hello'")
# Out:
# he said 'hello'

# %%
print('he said "hello"')
# Out:
# he said "hello"
